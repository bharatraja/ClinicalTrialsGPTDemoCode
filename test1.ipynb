# %%
import threading
import time
 
def test(name, name1):
    time.sleep(.01)
    print("run "+ name + name1)
 
ts = []
 
#create 10 threads 
for i in range(1000):
    thread_name = 'thread ' + str(i)
    th = threading.Thread(target=test, args=[thread_name, thread_name])
    ts.append(th)

# %%
#Not a predicatable order of whe threads are started
for t in ts:
    t.start()
# Out:
# run thread 1thread 1
# run thread 0thread 0
# run thread 9thread 9
# run thread 8thread 8
# run thread 7thread 7
# run thread 6thread 6
# run thread 5thread 5
# run thread 4thread 4
# run thread 3thread 3
# run thread 2thread 2

# %%
#concurrent

for i in ts:
    i.start()
    i.join()
# Out:
# run thread 0thread 0
# run thread 1thread 1
# run thread 2thread 2
# run thread 3thread 3
# run thread 4thread 4
# run thread 5thread 5
# run thread 6thread 6
# run thread 7thread 7
# run thread 8thread 8
# run thread 9thread 9
# run thread 10thread 10
# run thread 11thread 11
# run thread 12thread 12
# run thread 13thread 13
# run thread 14thread 14
# run thread 15thread 15
# run thread 16thread 16
# run thread 17thread 17
# run thread 18thread 18
# run thread 19thread 19
# run thread 20thread 20
# run thread 21thread 21
# run thread 22thread 22
# run thread 23thread 23
# run thread 24thread 24
# run thread 25thread 25
# run thread 26thread 26
# run thread 27thread 27
# run thread 28thread 28
# run thread 29thread 29
# run thread 30thread 30
# run thread 31thread 31
# run thread 32thread 32
# run thread 33thread 33
# run thread 34thread 34
# run thread 35thread 35
# run thread 36thread 36
# run thread 37thread 37
# run thread 38thread 38
# run thread 39thread 39
# ...

# %%
import threading
from queue import Queue

class ThreadBot(threading.Thread):  
  def __init__(self):
    super().__init__(target=self.manage_table)  
    self.cutlery = Cutlery(knives=0, forks=0)  
    self.tasks = Queue()  

  def manage_table(self):
    while True:  
      task = self.tasks.get()
      if task == 'prepare table':
        kitchen.give(to=self.cutlery, knives=4, forks=4) 
      elif task == 'clear table':
        self.cutlery.give(to=kitchen, knives=4, forks=4)
      elif task == 'shutdown':
        return
      

from attr import attrs, attrib

@attrs  
class Cutlery:
    knives = attrib(default=0)  
    forks = attrib(default=0)

    def give(self, to: 'Cutlery', knives=0, forks=0):  
        self.change(-knives, -forks)
        to.change(knives, forks)

    def change(self, knives, forks):  
            self.knives += knives
            self.forks += forks

kitchen = Cutlery(knives=100, forks=100)  
bots = [ThreadBot() for i in range(10)]  

import sys
for bot in bots:
    for i in range(int(sys.argv[1])):  
        bot.tasks.put('prepare table')
        bot.tasks.put('clear table')
    bot.tasks.put('shutdown')  

print('Kitchen inventory before service:', kitchen)
for bot in bots:
    bot.start()
